# %%
#entrada

celsius = int(input("qual a temperatura em graus: "))
faren = int(input("digite seu numero em farenheint: "))
res1 = celsius
res2 =

#saida

print(de {celsius} para)
# Out:
# qual a temperatura: 12
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_249/1786825267.py in <cell line: 0>()
#       3 celsius = int(input("qual a temperatura: "))
#       4
# ----> 5 faren + (celsius * 9 / 5 + 32)
#       6
#       7 #saida
#
# NameError: name 'faren' is not defined

# %%
#operadores aritimeticos

#fazer um programa em que o usuario digita 2 numero
#saida mostrar operaçoes aritmeticas

#entrada

a = int(input("digite um numero"))
b = int(input("digite um numero"))

#processamento

soma = a + b
sub = a - b
divi = a / b
multi = a * b
div_int = a // b
resto = a % b
potencia = a ** b

#saida

print("")
print("-----------------operadores aritimeticos--------------------------------")
print("")
print("------------------------------soma--------------------------------------")
print("")
print(f" o resultado da soma de {a} + {b} e igual a: {soma}")
print("")
print("---------------------------sub-------------------------------------------")
print(f" o resultado da soma de {a} - {b} e igual a {sub}")
print("")
print("---------------------------divi------------------------------------------")
print(f" o resultado da soma de {a} / {b} e igual a {divi}")
print("")
print("---------------------------multi----------------------------------------")
print("")
print(f" o resultado da soma de {a} * {b} e igual a {multi}")
print("")
print("------------------------------------------------------------------------")
print("")
print("---------------------------div_int--------------------------------------")
print("")
print(f" o resultado da soma de {a} // {b} e igual a {div_int}")
print("")
print("------------------------------------------------------------------------")
# Out:
# digite um numero10
# digite um numero20
#
# -----------------operadores aritimeticos--------------------------------
#
# ------------------------------soma--------------------------------------
#
#  o resultado da soma de 10 + 20 e igual a: 30
#
# ---------------------------sub-------------------------------------------
#  o resultado da soma de 10 - 20 e igual a -10
#
# ---------------------------divi------------------------------------------
#  o resultado da soma de 10 / 20 e igual a 0.5
#
# ---------------------------multi----------------------------------------
#
#  o resultado da soma de 10 * 20 e igual a 200
#
# ------------------------------------------------------------------------
#
# ---------------------------div_int--------------------------------------
#
#  o resultado da soma de 10 // 20 e igual a 0
#
# ------------------------------------------------------------------------

# %%
#horas em min

horas = int(input("digite seu numero em horas: "))
min = int(input("digite seu numero em minutos: "))
resultado = horas * 60
resultado2 = min * 60

print(f" em {horas} tem {resultado} min e em {min} min tem {resultado2} seg")
# Out:
# digite seu numero em horas: 10
# digite seu numero em minutos: 20
#  em 10 tem 600 min e em 20 min tem 1200 seg

# %%
#km em metros
km = int(input("digite seu numeros em km: "))
m = int(input("digite seu numeros em m: "))
res1= m / 1000
res2 = km * 1000

print(f"em {m} metros tem {res1} km's e em {km} kilometros tem {res2} metros")
# Out:
# digite seu numeros em km: 1
# digite seu numeros em m: 1000
# em 1000 metros tem 1.0 km's e em 1 kilometros tem 1000 metros

# %%
#km em milhas
km = float(input(" digite seu numero em km para milhas:  "))
milhas = float(input("digite seu numero em milhas para km:  "))
res1 = km / 1609
res2 = milhas * 1609
print(f"em {km} km para {res1} milhas e de {milhas} milhas para {res2}")
# Out:
#  digite seu numero em km para milhas:  10
# digite seu numero em milhas para km:  10
# em 10.0 km para 0.006215040397762586 milhas e de 10.0 milhas para 16090.0
