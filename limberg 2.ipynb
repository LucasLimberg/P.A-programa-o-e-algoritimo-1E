# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasLimberg/P.A-programa-o-e-algoritimo-1E/blob/main/limberg%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calcula área do retangulo

# entrada

comprimento = float (input("digite o valor do comprimento: "))
altura = float  (input("digite o valor da altura: "))

# processamento

area = comprimento * altura

#saida

print(f"A area do retangulo e igual: {area}")
# Out:
# digite o valor do comprimento: 10
# digite o valor da altura: 10
# A area do retangulo e igual: 100.0

# %%
# escreva um programa que calcula a o dobro de um número

# entrada

numero = int (imput(" digite seu numero:"))

# processamento

dobro = numero * 2

# saida

print(f"O dobro de {numero} e igual a: {dobro}")

# %%
# Escrever um cadastro de usuario
# entrada : nome e idade
# processamento  : armazenar os dados do usuario
# saída : mostra uma mensagem de boas vindas e o nome e a idade do usuário

#entrada

nome = str(input ("digite o seu nome: "))
idade = int(input("digite sua idade: "))

# processamento

#saída

print (f"ola {nome}, seja bem vindo!")
print (f" voce tem {idade}")
# Out:
# digite o seu nome: oifhrweo
# digite sua idade: 14
# ola oifhrweo, seja bem vindo!
#  voce tem 14

# %% [markdown]
# escrever um programa que receba o nome do usuario e a idade e mostre uma mensagem com o ano que ele nasceu.

# %%
# Converter Celsius para Fahrenheit

celsius = float(input("Digite a temperatura em Celsius: "))

fahrenheit = (celsius * 9/5) + 32

print("Temperatura em Fahrenheit:", fahrenheit)
# Out:
# Digite a temperatura em Celsius: 30
# Temperatura em Fahrenheit: 86.0
