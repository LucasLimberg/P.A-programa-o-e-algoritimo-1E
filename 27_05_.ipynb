# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasLimberg/P.A-programa-o-e-algoritimo-1E/blob/main/27_05_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#jogo menu inteligente

# criar um sistema que funcione ate o usuario escolher sair

#menu

# 1- par/ impar
# 2- postivo negativo
# 3- maior
# 4- sair

opcao = 0
while opcao != 4:
  print("--------------MENU-----------------")
  print("--------------opçao1-----------------")
  print("--------------opcao2-----------------")
  print("--------------opcao3-----------------")
  print("--------------opcao4-----------------")
  opcao = int(input(" escolha uma das 4 opçoes:  "))

  if opcao == 1:
    numero = int(input("digite um numero par ou impar:  "))
    if opcao % 2 == 0:
      print("seu numero e par")
    else:
      print("seu numero e impar")

  elif opcao == 2:
   numero = int(input(" digite um numero:  "))
   if numero >= 0:
    print("seu numero e postivo")
   else:
    print(" seu numero e negativo")

  elif opcao == 3:
    numero = int(input(" digite um numero:  "))
    numero1 = int(input(" digite um numero:  "))
    if numero > numero1:
      print(f"o numero {numero} e maior que o {numero1}")

    else:
      print(f"o numero{numero1} e maior que o {numero}")

  elif opcao == 4:
    print("voce saiu")

# %%
# urna eletronica

# criar um programa de votçao# Urna Eletrônica

# Criar um programa de votação com 3 candidatos

# Votar candidato A
# Votar candidato B
# Votar candidato C
# Votar Branco
# Votar Nulo
# Encerrar votação

# O sistema deve repetir até encerrar a votação
# Contar votos de cada candidato
# Contar votos brancos e nulos
# Ao encerra, mostrar:

# Total de Votos
# Total de votos por candidato
# Total votos brancos
# Total votos nulos
# Vencedor da eleição

# Regras extras

#
# Se houver empate entre candidatos: mostrar eleicao empatada
# se nao houver votos validos mostra: nenhum candidato recebeu votos

votos_candidato2 = 0
votos_candidato3 = 0
votos_brancos = 0
votos_nulos = 0
total_votos_registrados = 0

print("--- Urna Eletrônica ---")
print("Candidatos:")
print("  1 - Candidato A")
print("  2 - Candidato B")
print("  3 - Candidato C")
print("  0 - Voto em Branco")
print("  Qualquer outro número inteiro para Voto Nulo")
print("  Digite 99 para encerrar a votação a qualquer momento.")

while True:
    try:
        voto = int(input("Digite seu voto: "))

        if voto == '99':
            print("Votação encerrada.")
            break

        voto_int = int(voto)

        if voto_int == 1:
            votos_candidato1 += 1
        elif voto_int == 2:
            votos_candidato2 += 1
        elif voto_int == 3:
            votos_candidato3 += 1
        elif voto_int == 0:
            votos_brancos += 1
        else:
            votos_nulos += 1

        total_votos_registrados += 1
        print("Voto registrado com sucesso!")

    except ValueError:
        print("Entrada inválida. Por favor, digite um número inteiro.")

        votos_nulos += 1
        total_votos_registrados += 1

print("\n--- Resultado da Votação ---")
print(f"Total de votos registrados: {total_votos_registrados}")
print(f"Votos para Candidato A: {votos_candidato1}")
print(f"Votos para Candidato B: {votos_candidato2}")
print(f"Votos para Candidato C: {votos_candidato3}")
print(f"Votos em Branco: {votos_brancos}")
print(f"Votos Nulos: {votos_nulos}")


total_valid_votes = votos_candidato1 + votos_candidato2 + votos_candidato3

if total_valid_votes == 0:
    print("Nenhum candidato recebeu votos válidos.")
else:
    max_votos = votos_candidato1
    if votos_candidato2 > max_votos:
        max_votos = votos_candidato2
    if votos_candidato3 > max_votos:
# Out:
#   File "/tmp/ipykernel_1214/544356951.py", line 95
#
#     ^
# SyntaxError: incomplete input
