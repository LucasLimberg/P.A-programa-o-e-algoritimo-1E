# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasLimberg/P.A-programa-o-e-algoritimo-1E/blob/main/limberg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula de programaçâoe algoritmos
# *   calculo de árera
# #entrada
# *   ler lado1
# *   ler lado2
# # processamento
# area= lado1 * lado2
# #saida
# imprimir área

# %%
#calculo da área

#entrada

lado_1 = 8

lado_2 = 8

#tipos numericos

nome = "limberg"
idade = 25 # int
altura = 1.75  #float
numero_complexo = 2 + 3j #complex

# tipo booleana
esta_chovendo = False #boo1

# %%
# processameno


area = lado_1 * lado_2

# %%
# saída

print (f"total da área: {area}")
# Out:
# total da área: 64
